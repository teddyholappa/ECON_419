# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
"""
Variables to include
: PWSSWGT, PWCMPWGT,PESEX,PEMARITL,
: PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,
: HEFAMINC,PEHSPNON
"""
# Out:
# '\nVariables to include\n: PWSSWGT, PWCMPWGT,PESEX,PEMARITL,\n: PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,\n: HEFAMINC,PEHSPNON\n'

# %%
mar_2021 = 'https://api.census.gov/data/2021/cps/basic/mar?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
feb_2021 = 'https://api.census.gov/data/2021/cps/basic/feb?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
jan_2021 = 'https://api.census.gov/data/2021/cps/basic/jan?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
dec_2020 = 'https://api.census.gov/data/2020/cps/basic/dec?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
nov_2020 = 'https://api.census.gov/data/2020/cps/basic/nov?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
oct_2020 = 'https://api.census.gov/data/2020/cps/basic/oct?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
sep_2020 = 'https://api.census.gov/data/2020/cps/basic/sep?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
aug_2020 = 'https://api.census.gov/data/2020/cps/basic/aug?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
jul_2020 = 'https://api.census.gov/data/2020/cps/basic/jul?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
jun_2020 = 'https://api.census.gov/data/2020/cps/basic/jun?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
may_2020 = 'https://api.census.gov/data/2020/cps/basic/may?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
apr_2020 = 'https://api.census.gov/data/2020/cps/basic/apr?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
mar_2020 = 'https://api.census.gov/data/2020/cps/basic/mar?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
feb_2020 = 'https://api.census.gov/data/2020/cps/basic/feb?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'
jan_2020 = 'https://api.census.gov/data/2020/cps/basic/jan?get=PWSSWGT,PWCMPWGT,PESEX,PEMARITL,PEEDUCA,PTDTRACE,PRCITSHP,PREXPLF,HEFAMINC,PEHSPNON&ucgid=0400000US01,0400000US02,0400000US04,0400000US05,0400000US06,0400000US08,0400000US09,0400000US10,0400000US11,0400000US12,0400000US13,0400000US15,0400000US16,0400000US17,0400000US18,0400000US19,0400000US20,0400000US21,0400000US22,0400000US23,0400000US24,0400000US25,0400000US26,0400000US27,0400000US28,0400000US29,0400000US30,0400000US31,0400000US32,0400000US33,0400000US34,0400000US35,0400000US36,0400000US37,0400000US38,0400000US39,0400000US40,0400000US41,0400000US42,0400000US44,0400000US45,0400000US46,0400000US47,0400000US48,0400000US49,0400000US50,0400000US51,0400000US53,0400000US54,0400000US55,0400000US56'

# %%
#Setting names of each df, and prepping for saving them to .csv
req_list = [jan_2020, feb_2020, mar_2020, apr_2020, may_2020, jun_2020, jul_2020, aug_2020, sep_2020, oct_2020,
            nov_2020, dec_2020, jan_2021, feb_2021, mar_2021]
names = ['jan_2020', 'feb_2020', 'mar_2020', 'apr_2020', 'may_2020', 'jun_2020', 'jul_2020', 'aug_2020', 'sep_2020', 'oct_2020',
            'nov_2020', 'dec_2020', 'jan_2021', 'feb_2021', 'mar_2021']
df_list = []

# %%
states = ['AL','AK','AZ','AR','CA','CO','CT','DE',
         'DC','FL','GA','HI','ID','IL','IN','IA','KA',
         'KY','LA','ME','MD','MA','MI','MN','MS','MO',
         'MT','NE','NV','NH','NJ','NM','NY','NC','ND',
         'OH','OK','OR','PA','RI','SC','SD','TN','TX','UT',
         'VT','VA','WA','WV','WI','WY']
states_dict = {
        '1':1,'2':2,'4':3,'5':4,'6':5,'8':6,'9':7,
        '10':8,'11':9,'12':10,'13':11,'15':12,'16':13,'17':14,
        '18':15,'19':16,'20':17,'21':18,'22':19,'23':20,'24':21,
        '25':22,'26':23,'27':24,'28':25,'29':26,'30':27,'31':28,
        '32':29,'33':30,'34':31,'35':32,'36':33,'37':34,'38':35,
        '39':36,'40':37,'41':38,'42':39,'44':40,'45':41,'46':42,
        '47':43,'48':44,'49':45,'50':46,'51':47,'53':48, '54':49,
        '55':50,'56':51
}
m_status = ['Married_Spouse_Present', 'Married_Spouse_Absent',
            'Widowed','Divorced','Separated','Never_Married']
education = ['No_Diploma','High_school','Some_college','Associates','Bachelors','Masters','PhD']
race = ['White','Black','HP','Asian','American_Indian']
citizenship = ['Native_Citizen','Naturalized_Citizen','Non_Citizen']

# %%
from sklearn.preprocessing import LabelBinarizer
def one_hot_encode(df,columns, col_name):
    y = LabelBinarizer().fit_transform(df[col_name])
    one_hot = pd.DataFrame(index=df.index,data=y,columns=columns)
    return one_hot

# %%
def drop_out_of_universe(df):
    df = df[df.PESEX != '-1']
    df = df[df.PEMARITL != '-1']
    #Removing pre-high school values
    '''
    1 - no high school diploma
    2-high school grad
    3 - Some college
    4 - Associates degree
    5 - Bachelor's
    6 - Master's
    7 - PHD or professional school
    '''
    bad_educ_vals = ['31','32','33','34','35','36','37'] #replace these with -1
    df['PEEDUCA'] = df['PEEDUCA'].replace(bad_educ_vals,'-1')
    df['PEEDUCA'] = df['PEEDUCA'].replace(['38','39','40','41','42','43','44','45','46'],[1,2,3,4,4,5,6,7,7])
    df = df[df.PEEDUCA != '-1']
    df = df[df.PEEDUCA != -1]
    bad_race_values = ['26','25','24','23','22','21','20','19','18','17',
                      '16','10','5','13','14','15']
    df['PTDTRACE'] = df['PTDTRACE'].replace(bad_race_values,-1)
    '''
    White = 1
    Black = 2
    Non-white hispanic = 3
    Asian = 4
    AI = 5
    '''
    df['PTDTRACE'] = df['PTDTRACE'].replace(['1','2','3','4','6','7','8','9','10','11','12'],[1,2,5,4,2,5,4,1,2,2,3])
    df = df[df.PTDTRACE != '-1']
    df = df[df.PTDTRACE != -1]
    #Change everyone labeled hispanic to hispanic in PTDTRACE
    #Annoying how these are separated variables
    df.loc[df.PEHSPNON == '1', 'PTDTRACE'] = 3 
    df['PRCITSHP'] = df['PRCITSHP'].replace(['1','2','3','4','5'],[1,1,1,2,3])
    df = df[df.PRCITSHP != '-1']
    df = df[df.PREXPLF != '-1']
    df['STATE'] = df['STATE'].replace(states_dict)
    df = df.drop(columns=['PWSSWGT','PWMCMPWGT','PEHSPNON'])
    return df

# %%
cols = ['PWSSWGT','PWMCMPWGT','PESEX','PEMARITL','PEEDUCA',
        'PTDTRACE','PRCITSHP','PREXPLF','HEFAMINC', 'PEHSPNON','STATE']

# %%
df_list = []
for i in range(len(req_list)):
    print("Iteration: ", i)
    #Begin the one_hot_encoding process
    request = req_list[i]
    response = requests.get(request)
    name = names[i] +".csv"
    query = json.loads(response.text)[1:]
    df = pd.DataFrame(columns=cols, data=query)
    #Drop out of universe values
    df = drop_out_of_universe(df)
    #print(df.columns)
    #PESEX
    pesex_one = pd.to_numeric(df['PESEX']) - 1
    #PEMARITL
    premaritl_one = one_hot_encode(df,m_status,'PEMARITL')
    #PEEDUCA - this one is more complicated
    #We don't necessarily need to one hot encode this, as it has a scale!!!
    #peeduca_one = one_hot_encode(df,education,'PEEDUCA')
    peeduca_one = df['PEEDUCA']
    #PTDTRACE
    ptdtrace_one = one_hot_encode(df, race, 'PTDTRACE')
    #PRCITSHP
    prcitshp_one = one_hot_encode(df,citizenship,'PRCITSHP')
    #PREEXPLF - already one hot encoded
    preexplf_one = pd.to_numeric(df['PREXPLF']) - 1
    #HEFAMINC - income level
    hefaminc = pd.to_numeric(df['HEFAMINC'])
    #STATE
    states_one = one_hot_encode(df,states,'STATE')
    #Create the one hot encoded dataframe!
    result = pd.concat([preexplf_one, hefaminc, pesex_one,peeduca_one, premaritl_one,ptdtrace_one,
                       prcitshp_one,states_one],axis=1)
    #Add it to the df_list
    df_list.append(result)
    result.to_csv('all_data/' + name)
# Out:
# Iteration:  0
# Iteration:  1
# Iteration:  2
# Iteration:  3
# Iteration:  4
# Iteration:  5
# Iteration:  6
# Iteration:  7
# Iteration:  8
# Iteration:  9
# Iteration:  10
# Iteration:  11
# Iteration:  12
# Iteration:  13
# Iteration:  14

# %%
#Time to regress
regression_list = []
import statsmodels.api as sm
for i in range(len(df_list)):
    df = df_list[i]
    df = df.drop(columns=['AK','Native_Citizen','White','Separated'])
    X = df.drop('PREXPLF',axis=1)
    Y = df['PREXPLF']
    logit = sm.Logit(Y,X).fit(disp=0)
    regression_list.append(logit)

# %%
reg = regression_list[1]
#reg.summary()
df = df_list[2]
df.columns
# Out:
# Index(['PREXPLF', 'HEFAMINC', 'PESEX', 'PEEDUCA', 'Married_Spouse_Present',
#        'Married_Spouse_Absent', 'Widowed', 'Divorced', 'Separated',
#        'Never_Married', 'White', 'Black', 'HP', 'Asian', 'American_Indian',
#        'Native_Citizen', 'Naturalized_Citizen', 'Non_Citizen', 'AL', 'AK',
#        'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL',
#        'IN', 'IA', 'KA', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO',
#        'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR',
#        'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI',
#        'WY'],
#       dtype='object')

# %%
#Create time series for each state
#Remember, we remoce AK here to avoid dummy variable trap!!!
states = ['AL','AZ','AR','CA','CO','CT','DE',
         'DC','FL','GA','HI','ID','IL','IN','IA','KA',
         'KY','LA','ME','MD','MA','MI','MN','MS','MO',
         'MT','NE','NV','NH','NJ','NM','NY','NC','ND',
         'OH','OK','OR','PA','RI','SC','SD','TN','TX','UT',
         'VT','VA','WA','WV','WI','WY']
state_dict = {state:[] for state in states}
coef = []
for reg in regression_list:
    for state in states:
        coef = reg.params[state]
        state_dict[state].append(coef)

# %%
#Cluster the values - this doesn't seem to work, VT and DC are in same cluster!
columns = states
idx = names
states_df = pd.DataFrame(columns=columns,index=idx)
for state in states:
    states_df[state] = state_dict[state]

from sklearn.cluster import KMeans
import numpy as np

kmeans = KMeans(n_clusters=2).fit(states_df.T)
kmeans = kmeans.predict(states_df.T)
clustering = pd.DataFrame(data=kmeans,index=states,columns=['Label'])
#clustering = clustering.sort_values(by=index)
clustering.to_csv("cluster.csv")
#the map is saved to the Adv Econometrics/Project/MAP

# %%
key = states_df.T.index.values
key_df = pd.DataFrame(data=states_df.T.index.values,columns=['State'])

# %%
from sklearn.manifold import TSNE
from bioinfokit.visuz import cluster
tsne_em = TSNE(n_components = 2, perplexity=10.0,n_iter=1000,verbose=1).fit_transform(states_df.T)
cluster.tsneplot(score=tsne_em)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 50 samples in 0.000s...
# [t-SNE] Computed neighbors for 50 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 50 / 50
# [t-SNE] Mean sigma: 0.539141
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.766144
# [t-SNE] KL divergence after 1000 iterations: 0.232575

# %%
tsne_df = pd.DataFrame(data=tsne_em, columns=['X','Y'],index=key_df.index)
#tsne_df = pd.concat([tsne_df,key_df])
tsne_df['State'] = key_df['State']

# %%
#TSNE PLOT
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('X',fontsize=15)
ax.set_ylabel('Y',fontsize=15)
ax.set_title('2 Component TSNE',fontsize=20)
ax.scatter(tsne_df['X'],tsne_df['Y'])
for i in range(50):
    ax.annotate(tsne_df['State'][i],(tsne_df['X'][i],tsne_df['Y'][i]))

# %%
#PCA
key_df = pd.DataFrame(data=states_df.T.index.values,columns=['State'])
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(states_df.T)
principal_df = pd.DataFrame(data=principalComponents,columns=['PC1','PC2'])
principal_df = pd.concat([principal_df,key_df],axis=1)
#Plot the PCA
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('PC1',fontsize=15)
ax.set_ylabel('PC2',fontsize=15)
ax.set_title('2 Component PCA',fontsize=20)
ax.scatter(principal_df['PC1'],principal_df['PC2'])
for i in range(50):
    ax.annotate(principal_df['State'][i],(principal_df['PC1'][i],principal_df['PC2'][i]))

# %%
import matplotlib.pyplot as plt
import numpy as np
names = ['01/20', '02/20', '03/20', '04/20', '05/20', '06/20', '07/20', '08/20', '09/20', '10/20',
            '11/20', '12/20', '01/21', '02/21', '03/21']
plt.figure(figsize=(10,5))
#plt.plot(names, state_dict['DC'], label='DC')
#plt.plot(names,state_dict['VT'],label='VT')
#plt.plot(names,state_dict['FL'],label='FL')
#plt.plot(names,state_dict['IA'],label='IA')
#plt.plot(names,state_dict['ME'],label='ME')
#plt.plot(names,state_dict['NH'],label='NH')
for state in states:
    if state in ['IA','MN']:
        plt.plot(names,state_dict[state],label=state)
plt.axvline(x=1.5, label='First cast in VA',c='r')
plt.axvline(x=1.4, label='First cast in NC',c='b')

plt.legend()
plt.show()

# %%
#Set up the ordered probit Stata files
#If PREXPLF == 1 -> unemployed
#Question here: Should we only do ordered probit on people who are employed?
names = ['jan_2020', 'feb_2020', 'mar_2020', 'apr_2020', 'may_2020', 'jun_2020', 'jul_2020', 'aug_2020', 'sep_2020', 'oct_2020',
            'nov_2020', 'dec_2020', 'jan_2021', 'feb_2021', 'mar_2021']
for i in range(len(df_list)):
    name = names[i] + ".dta"
    df = df_list[i]
    df = df.drop(columns=['AK','Native_Citizen','White','Separated'])
    #df = df[df['PREXPLF'] == 1]
    save = "Stata/"+name
    df.to_stata(save)

# %%
#Fixing a string so that we can actually write oprobit in Stata
everything = ""
for element in df.columns:
    if element == "HEFAMINC":
        continue
    else:
        everything += element+" "
everything
# Out:
# 'PREXPLF PESEX PEEDUCA Married_Spouse_Present Married_Spouse_Absent Widowed Divorced Never_Married Black HP Asian American_Indian Naturalized_Citizen Non_Citizen AL AZ AR CA CO CT DE DC FL GA HI ID IL IN IA KA KY LA ME MD MA MI MN MS MO MT NE NV NH NJ NM NY NC ND OH OK OR PA RI SC SD TN TX UT VT VA WA WV WI WY '

# %%
""
